# %%
### Get Fundamentals from Finviz ###
import finviz
finviz.get_stock('AAPL')
# Out:
# {'Company': 'Apple Inc.',
#  'Sector': 'Technology',
#  'Industry': 'Consumer Electronics',
#  'Country': 'USA',
#  'Index': 'DJIA S&P500',
#  'P/E': '35.53',
#  'EPS (ttm)': '3.29',
#  'Insider Own': '0.07%',
#  'Shs Outstand': '17.25B',
#  'Perf Week': '-3.56%',
#  'Market Cap': '2027.15B',
#  'Forward P/E': '30.17',
#  'EPS next Y': '19.46%',
#  'Insider Trans': '-6.66%',
#  'Shs Float': '17.09B',
#  'Perf Month': '4.53%',
#  'Income': '58.42B',
#  'PEG': '2.82',
#  'EPS next Q': '0.71',
#  'Inst Own': '62.10%',
#  'Short Float': '0.52%',
#  'Perf Quarter': '25.88%',
#  'Sales': '273.86B',
#  'P/S': '7.40',
#  'EPS this Y': '-2.60%',
#  'Inst Trans': '-0.17%',
#  'Short Ratio': '0.51',
#  'Perf Half Y': '69.97%',
#  'Book/sh': '4.19',
#  'P/B': '27.89',
#  'ROA': '17.70%',
#  'Target Price': '121.43',
#  'Perf Year': '94.82%',
#  'Cash/sh': '5.36',
#  'P/C': '21.79',
#  'EPS next 5Y': '12.60%',
#  'ROE': '70.70%',
#  '52W Range': '53.15 - 137.98',
#  'Perf YTD': '59.20%',
# ...

# %%
### Get Fundamentals from InvestPy ###
import investpy
investpy.get_stock_company_profile(stock='AAPL', country='united states', language='english')
# Out:
# {'url': 'https://www.investing.com/equities/apple-computer-inc-company-profile',
# ...

# %%
### Get Fundamentals from InvestPy (Dividens) ###
import investpy
investpy.stocks.get_stock_dividends(stock='AAPL', country='united states')
# Out:
#          Date  Dividend                    Type Payment Date  Yield
# 0  2020-08-31     0.205               quarterly   2020-08-28  0,70%
# 1  2020-08-07     0.820               quarterly   2020-08-13  0,72%
# 2  2020-05-08     0.820               quarterly   2020-05-14  0,86%
# 3  2020-02-07     0.770               quarterly   2020-02-13  1,07%
# 4  2019-11-07     0.770               quarterly   2019-11-14  1,00%
# ..        ...       ...                     ...          ...    ...
# 58 1989-11-17     0.110  trailing_twelve_months   1989-11-24      -
# 59 1989-08-21     0.100  trailing_twelve_months   1989-08-28      -
# 60 1989-05-22     0.100  trailing_twelve_months   1989-05-29      -
# 61 1989-02-17     0.100  trailing_twelve_months   1989-02-24      -
# 62 1988-11-21     0.100  trailing_twelve_months   1988-11-28      -
#
# [63 rows x 5 columns]

# %%
### Get Fundamentals from Yahoo_Fin ###
from yahoo_fin.stock_info import get_analysts_info
get_analysts_info('AAPL')
# Out:
# {'Earnings Estimate':   Earnings Estimate  Current Qtr. (Sep 2020)  Next Qtr. (Dec 2020)  \
#  0   No. of Analysts                    30.00                 26.00
#  1     Avg. Estimate                     0.71                  1.36
#  2      Low Estimate                     0.54                  1.19
#  3     High Estimate                     0.86                  1.70
#  4      Year Ago EPS                     0.76                  1.25
#
#     Current Year (2020)  Next Year (2021)
#  0                37.00             37.00
#  1                 3.24              3.87
#  2                 3.08              3.17
#  3                 3.40              4.50
#  4                 2.97              3.24  ,
#  'Revenue Estimate':           Revenue Estimate Current Qtr. (Sep 2020) Next Qtr. (Dec 2020)  \
#  0          No. of Analysts                      27                   25
#  1            Avg. Estimate                  64.16B              100.22B
# ...

# %%
### Get Fundamentals from Yahoo_Fin (Balance Sheet) ###
from yahoo_fin.stock_info import get_balance_sheet
get_balance_sheet('AAPL')
# Out:
#                                   Breakdown  9/30/2019  9/30/2018  9/30/2017
# 0                              Total Assets  338516000  365725000  375319000
# 1   Total Liabilities Net Minority Interest  248028000  258578000  241272000
# 2      Total Equity Gross Minority Interest   90488000  107147000  134047000
# 3                      Total Capitalization  182295000  200882000  231254000
# 4                       Common Stock Equity   90488000  107147000  134047000
# 5                       Net Tangible Assets   90488000  107147000  126032000
# 6                           Working Capital   57101000   14473000   27831000
# 7                          Invested Capital  198535000  221630000  249727000
# 8                       Tangible Book Value   90488000  107147000  126032000
# 9                                Total Debt  108047000  114483000  115680000
# 10                                 Net Debt   59203000   88570000   95391000
# ...

# %%
### Get Fundamentals from Yahoo_Fin (Cash Flow) ###
from yahoo_fin.stock_info import get_cash_flow
get_cash_flow('AAPL')
# Out:
#                             Breakdown        ttm  9/30/2019  9/30/2018  \
# 0                 Operating Cash Flow   80008000   69391000   77434000
# 1                 Investing Cash Flow  -10618000   45896000   16066000
# 2                 Financing Cash Flow  -86502000  -90976000  -87876000
# 3                   End Cash Position   35039000   50224000   25913000
# 4   Income Tax Paid Supplemental Data   11878000   15263000   10417000
# 5     Interest Paid Supplemental Data    3135000    3423000    3022000
# 6                 Capital Expenditure   -8302000  -10495000  -13313000
# 7           Issuance of Capital Stock     820000     781000     669000
# 8                    Issuance of Debt   22794000    6963000    6969000
# 9                   Repayment of Debt  -13908000   -8805000   -6500000
# 10        Repurchase of Capital Stock  -72615000  -66897000  -72738000
# 11                     Free Cash Flow   71706000   58896000   64121000
#
#     9/30/2017
# 0    63598000
# ...

# %%
### Get Fundamentals from Yahoo_Fin (Day Gainers) ###
from yahoo_fin.stock_info import get_day_gainers
get_day_gainers()
# Out:
#    Symbol                          Name  Price (Intraday)  Change  % Change  \
# 0    BTGN       Bitcoin Generation Inc.              0.65    0.30     85.71
# 1    SNAP                     Snap Inc.             36.50    8.05     28.30
# 2    WDFC                 WD-40 Company            234.61   37.11     18.79
# 3     HAE       Haemonetics Corporation            105.91   11.46     12.13
# 4   MITUY        Mitsui Chemicals, Inc.             13.57    1.43     11.83
# ..    ...                           ...               ...     ...       ...
# 95  KDDIY              KDDI Corporation             13.33    0.43      3.33
# 96    CIT                CIT Group Inc.             27.88    0.82      3.03
# 97    PEN                Penumbra, Inc.            219.41    6.83      3.21
# 98    BHC  Bausch Health Companies Inc.             17.57    0.55      3.23
# 99    CAJ                    Canon Inc.             16.11    0.50      3.20
#
# ...

# %%
### Get Fundamentals from Yahoo_Fin (Day Losers) ###
from yahoo_fin.stock_info import get_day_losers
get_day_losers()
# Out:
#    Symbol                                    Name  Price (Intraday)  Change  \
# 0     GSX                        GSX Techedu Inc.             71.06  -31.88
# 1     JKS            JinkoSolar Holding Co., Ltd.             68.61  -18.94
# 2   FBASF                               Fibra UNO              0.73   -0.17
# 3      DQ                   Daqo New Energy Corp.            199.11  -42.88
# 4   CELTF                            Centamin plc              1.80   -0.33
# ..    ...                                     ...               ...     ...
# 95    COF       Capital One Financial Corporation             73.72   -3.55
# 96   APAM  Artisan Partners Asset Management Inc.             43.44   -2.08
# 97    MTH              Meritage Homes Corporation            103.42   -4.89
# 98    KMT                         Kennametal Inc.             32.66   -1.54
# 99   SRNE             Sorrento Therapeutics, Inc.              7.85   -0.37
#
# ...

# %%
### Get Fundamentals from Yahoo_Fin (Income Statement) ###
from yahoo_fin.stock_info import get_income_statement
get_income_statement('AAPL')
# Out:
#                                             Breakdown        ttm  9/30/2019  \
# 0                                       Total Revenue  273857000  260174000
# 1                                     Cost of Revenue  169277000  161782000
# 2                                        Gross Profit  104580000   98392000
# 3                                   Operating Expense   37442000   34462000
# 4                                    Operating Income   67138000   63930000
# 5           Net Non Operating Interest Income Expense    1052000    1385000
# 6                                Other Income Expense     127000     422000
# 7                                       Pretax Income   68317000   65737000
# 8                                       Tax Provision    9893000   10481000
# 9                      Net Income Common Stockholders   58424000   55256000
# 10           Diluted NI Available to Com Stockholders   58424000   55256000
# ...

# %%
### Get Fundamentals from Yahoo_Fin (Dow Jones Tickers List) ###
from yahoo_fin.stock_info import tickers_dow
tickers_dow()
# Out:
# ['AAPL',
#  'AMGN',
#  'AXP',
#  'BA',
#  'CAT',
#  'CRM',
#  'CSCO',
#  'CVX',
#  'DIS',
#  'DOW',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'KO',
#  'MCD',
#  'MMM',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'TRV',
#  'UNH',
#  'V',
#  'VZ',
#  'WBA',
#  'WMT']

# %%
### Get Fundamentals from Yahoo_Fin (Nasdaq Tickers List) ###
from yahoo_fin.stock_info import tickers_nasdaq
tickers_nasdaq()
# Out:
# ['AACQ',
#  'AACQU',
#  'AACQW',
#  'AAL',
#  'AAME',
#  'AAO',
#  'AAOI',
#  'AAPL',
#  'AAWW',
#  'AAX',
#  'AAXJ',
#  'ABCB',
#  'ABEO',
#  'ABIO',
#  'ABMD',
#  'ABTX',
#  'ABUS',
#  'ACAD',
#  'ACAM',
#  'ACAMU',
#  'ACAMW',
#  'ACBI',
#  'ACCD',
#  'ACER',
#  'ACET',
#  'ACEV',
#  'ACEVU',
#  'ACEVW',
#  'ACGL',
#  'ACGLO',
#  'ACGLP',
#  'ACHC',
#  'ACHV',
#  'ACIA',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACMR',
#  'ACNB',
#  'ACOR',
#  'ACRS',
#  'ACRX',
#  'ACST',
#  'ACT',
#  'ACTCU',
#  'ACTG',
#  'ACWI',
#  'ACWX',
#  'ADAP',
#  'ADBE',
#  'ADES',
#  'ADI',
#  'ADIL',
#  'ADILW',
#  'ADMA',
#  'ADMP',
#  'ADMS',
#  'ADP',
#  'ADPT',
#  'ADRE',
#  'ADSK',
#  'ADT',
#  'ADTX',
#  'ADUS',
#  'ADVM',
#  'ADX',
#  'ADXS',
#  'AEG',
#  'AEHL',
#  'AEHR',
#  'AEIS',
#  'AEMD',
#  'AEP',
#  'AEPPL',
#  'AEPPZ',
#  'AERI',
#  'AESE',
#  'AEY',
#  'AEYE',
#  'AEZS',
#  'AFI',
#  'AFIB',
#  'AFINP',
#  'AFMD',
#  'AFYA',
#  'AGBA',
#  'AGBAR',
#  'AGBAU',
#  'AGBAW',
#  'AGCUU',
# ...

# %%
### Get Fundamentals from Yahoo_Fin (S&P 500 Tickers List) ###
from yahoo_fin.stock_info import tickers_sp500
tickers_sp500()
# Out:
# ['A',
#  'AAL',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABC',
#  'ABMD',
#  'ABT',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'AEE',
#  'AEP',
#  'AES',
#  'AFL',
#  'AIG',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'ALXN',
#  'AMAT',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'ANET',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'APD',
#  'APH',
#  'APTV',
#  'ARE',
#  'ATO',
#  'ATVI',
#  'AVB',
#  'AVGO',
#  'AVY',
#  'AWK',
#  'AXP',
#  'AZO',
#  'BA',
#  'BAC',
#  'BAX',
#  'BBY',
#  'BDX',
#  'BEN',
#  'BF.B',
#  'BIIB',
#  'BIO',
#  'BK',
#  'BKNG',
#  'BKR',
#  'BLK',
#  'BLL',
#  'BMY',
#  'BR',
#  'BRK.B',
#  'BSX',
#  'BWA',
#  'BXP',
#  'C',
#  'CAG',
#  'CAH',
#  'CARR',
#  'CAT',
#  'CB',
#  'CBOE',
#  'CBRE',
#  'CCI',
#  'CCL',
#  'CDNS',
#  'CDW',
#  'CE',
#  'CERN',
#  'CF',
#  'CFG',
#  'CHD',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CINF',
#  'CL',
#  'CLX',
# ...
